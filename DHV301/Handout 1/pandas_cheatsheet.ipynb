# %%
# 1. Dùng khi nào: Khi bạn muốn gom nhóm dữ liệu theo một tiêu chí (như danh mục, ngày tháng) 
# để tính toán tổng hợp (sum, mean, count).
# Syntax: df.groupby('tên_cột')['cột_giá_trị'].hàm_tính_toán()

# %%
# 2. Dùng khi nào: Khi bạn có hai bảng dữ liệu riêng biệt và muốn kết hợp chúng lại dựa trên 
# một cột chung (giống như JOIN trong SQL).
# Syntax: pd.merge(df1, df2, on='cột_chung', how='inner/left/right/outer')

# %%
# 3. Dùng khi nào: Khi cần tạo bảng báo cáo đa chiều, xoay dữ liệu để so sánh giữa các 
# tiêu chí hàng và cột.
# Syntax: df.pivot_table(values='số_liệu', index='hàng', columns='cột', aggfunc='hàm')

# %%
# 4. Dùng khi nào: Khi bạn muốn thực hiện một tính toán phức tạp hoặc logic "if-else" 
# trên từng hàng hoặc từng cột mà các hàm có sẵn không làm được.
# Syntax: df['cột'].apply(tên_hàm)

# %%
# 5. Dùng khi nào: Khi dữ liệu đang ở dạng "ngang" (nhiều cột chứa cùng loại giá trị) 
# và bạn muốn chuyển thành dạng "dọc" để dễ vẽ biểu đồ hoặc phân tích.
# Syntax: pd.melt(df, id_vars=['cột_giữ_nguyên'], var_name='tên_cột_mới', value_name='giá_trị')
