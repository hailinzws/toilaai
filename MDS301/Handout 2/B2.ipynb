# %% [markdown]
# 2.1
# - Máy tự học dữ liệu để ra kết luận
# - Phải cần tự sửa thêm pattern, cập nhật logic
# - Dễ - máy tự xử lý
# - Thấp - Khó giải thích
# - Nhanh có logic là chạy được

# %% [markdown]
# 2.2
# Face unlock : Vision Supervised
# Google Translate : NPL Supervised
# Netflix : Analystic Unsupervised/Supervised
# Thẻ tín dụng : Analystic Supervised
# ChatGPT : NPL Supervised
# Xe tự lái : Other Others/Reinforce
# Spotify : Analystic Unsupervised
# Dự đoán giá cổ phiếu :Analystic Supervised

# %%
2.3 
a) Vì người ta chưa cung cấp đủ lượng data của cv phụ nữ và làm cho nó tưởng cv phụ nữ sẽ giỏi hơn nam và khiến nó bị bias
b) Cung cấp nhiều dataset hơn và đầy đủ số lượng cùng các case hơn
c) Có nhưng nó chỉ hỗ trợ đưa ra kết luận chứ không phải là người đưa ra quyết định cuối
